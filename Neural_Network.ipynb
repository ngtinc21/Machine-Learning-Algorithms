# %% [markdown]
# <a href="https://colab.research.google.com/github/ngtinc21/Machine-Learning-Algorithms/blob/main/Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Neural Network:**
#
# Neural networks reflect the behavior of the human brain, allowing computer programs to recognize patterns and solve common problems in the fields of AI, machine learning, and deep learning.
#
# It is constructed of layers with an input and output dimension.
# *   The input dimension is the number of features
# *   The output dimension is determined by the number of output neuron/nodes
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **1. Neuron**
#
# A neuron is the basic unit of neural network. It takes a group of weighted inputs (and a biase), applies an activation function, and returns an output.
#
# ![image.png](data:image/png;base64,...)
#
# *   Input(s) to the initial neuron can either be **feature(s) from a training set** or **output(s) from a previous layer's neurons**
# *   Weights are applied to the inputs as they travel along synapses to reach the neuron
# *   Function f is **non-linear** and is called the **activation function**
# *   **bias** is used for providing every node with a trainable constant value (in addition to the normal inputs that the node receives)

# %% [markdown]
# ## **2. Input Layers, Hidden Layers and Output Layers**
#
# *   Input layers:
#
#     Each neuron in the input layer represents a unique attribute in your dataset, i.e. the features of the dataset.
#
#
# *   Hidden layers:
#
#     An activation function is applied here before passing on the results. There are often multiple hidden layers in a network. The same application of activation function is repeated in these layers (forward propagation).
#
#     Traditional networks typically have fully-connected hidden layers -  each neuron receives input from all the previous layer’s neurons and sends its output to every neuron in the next layer.
#
# *   Output layers:
#
#     It receives input from the previous hidden layer, optionally applies an activation function, and returns an output representing your model’s prediction.
#     - The output layer shall have one output/neuron for a simple binary classifiation (essentially the same as logistic regression) or regression problem.
#     - There would be n outputs for multiclass classification with n different classes.

# %% [markdown]
# ## **3. Combining Neurons into a Neural Network**
# Neurons are connected by the layers to form a neural network.
#
# *   Single Layer Perceptron is the simplest (feedfoward) network. It has one layer only. It can learn linear relationship, essentially the same as linear regression.
#
# *   Multi Layer Perceptron has one or more hidden layers. It can learn non-linear relationship by Backpropagation algorithm. The algorithm is like “learning from mistakes“. The ANN output is compared with the desired output that was already knonw, and the error is “propagated” back to the previous layer.The supervisor thus corrects the weight of each synapse whenever it makes mistakes.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **4. Training a Neural Network**
#
# ## 4.1 Activation Function
# Activation functions lie inside the network layers. They modify data before passing to the next layer by non linear functions. They can allow neural networks to learn complex relationship from features.
#
#
# ## Common Characteristics of Activation Function
# *   Non-lineraity
#     - For learning non-linear pattern
# *   Continuously differentiable
#     - To improve the model with gradient descent so that slope of output will not be 0 or 1
#     - Otherwise, the model would not know in which direction to update our weights to reduce our error
# *   Fixed range
#     - To make the training process more stable and efficient

# %% [markdown]
# ## Popular Activation Functions:
# *   sigmoid
#         f(x) = 1/(1+e^-x)
#       - Usually for binary classification problems
#       - Output centred at 0.5 with a range from 0 to 1
#       - monotomic and differentiable function
#
#     BUT
#       - vanishing gradient - significant gradients values only in range from 3 to -3. The network cannot really learn beyond this range as the gradient approaches zero.
#       - function not symmetric at zero - output of all the neurons will be of the same sign
#
# *   tanh
#         tanh(x) = 2*sigmoid(2x)-1 or 2/(1+e^(-2x)) -1
#     - Almost the same function as sigmoid EXCEPT that its output is centred at 0 with a range from -1 to 1.
#     - No more restriction on gradients to have the same sign
#
# *   softmax
#
#   ![image.png](data:image/png;base64,...)
#
#     - For multiclass classification problems
#     - Outoputs are the probability for a datapoint belonging to each individual class
#     - Sum of all the output values is 1
#
# *   ReLu (Rectified Linear Unit)
#             f(x) = x if x >= 0,
#                  = 0 if x < 0
#     - No activation for all neurons at the same time
#     - Deactivate the neural if its output of linear transformation is less than 0
#     - More computationally efficient than the above two functions
#     - No vanishing gradient problem
#
#     BUT
#     - In case there might be dying relu problem, other relu modifications should be used, e.g. ELU, Swift (for layer>42)...
#     - Exploding Gradient problem
#     - function not symmetric at zero
#
#
# *   linear
#         f(x) = x
#
#     - For output layer in regression problems
#
# As a rule of thumb, one can begin with using ReLU function and then move over to other activation functions in case ReLU does not provide with optimum results

# %% [markdown]
# ## 4.2 Loss Function
#
# Before training the network, 'loss' should be specified to quantify how “good” the network is doing so that it can try to do “better.”
#
# Example of loss usage:
# *   Regression loss functions:
#     - mean square error (mse) - widely used when the distribution of the target variable is Gaussian
#     - mean squared logarithmic error (msle) - used for large range values of target variables
#     - mean absolute error (mae) - used whn the distribution of the target varirable is Gaussian, with large outliers
#
#
# *   Binary classification functions:
#     - binary cross-entropy (binary_crossentropy) - widely used for binary classification
#     - hinge - used with support vector machine (SVM) models
#
# *   Multiclass classification functions:
#     - multiclass cross-entropy Loss (categorical_crossentropy) - widely used for mutliclass classification
#     - sparse multiclass cross-entropy (sparse_categorical_crossentropy) - used for the same function as above but without requiring that the target variable be one hot encoded prior to training

# %% [markdown]
# ## 4.3 Optimization Function
#
# There are two main familty of optimazation function, namely the gradient descent optimizers and adaptive optimizers. An example of each is listed below:
#
# *   Mini-Batch Gradient Descent/Stochastic Gradient Descent (SGD)
#
#     - Possibility to have better performance than Adam for a good learning rate
#     - Less memory required
#
#     BUT
#     - Possibly to fine tune the learning rate for better performance
#     - Not good for sparse data
#     - Constant learning rate for all the parameters
#     - Possibility of getting stuck into a suboptimal local minima
#
# *   Adaptive Moment Estimation (Adam)
#
#     - No need to tune learning rate
#     - Good with sparse data
#
#     BUT
#     - Computationally costly

# %% [markdown]
# ## **5. Important Tools for Building a Neural Network**
# Keras is a convenient tool for constructing a neural network. It is a high-level API of TensorFlow 2:
#
# *   an approachable, simple, and highly-productive interface for solving machine learning problems, with a focus on modern deep learning.
#
# The core data structures of Keras are layers and models.
#
# The simplest type of model is the Sequential model, a linear stack of layers, which:
#
# *   each layer has exactly one input tensor and one output tensor
#
#         model = tf.keras.Sequential()
#
# For more complex architectures, the Keras Functional API should be used, which:
#
#         model = tf.keras.Model(inputs=input, outputs=output)
#
# *   the model has multiple inputs or multiple outputs
# *   any of the layers has multiple inputs or multiple outputs
# *   layer sharing has to be performed
# *   non-linear topology is desired, e.g. residual connection, multi-branch model
# *   allows to build arbitrary graphs of layers, or write models entirely from scratch
#
# ![image.png](data:image/png;base64,...)
